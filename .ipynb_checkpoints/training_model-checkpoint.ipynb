# %% [markdown]
# ***Lectura de Imágenes***

# %%
import os
import zipfile
import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.mixed_precision import Policy, set_global_policy

# %%
# Selección de clases
num_categories = 10

images_dir = os.path.join(os.path.dirname(os.getcwd()), "Clasificador-Minerales", "images_processed")
all_classes = sorted(os.listdir(images_dir))
selected_classes = all_classes[:num_categories]

# %%
# Generador de imágenes con aumento de datos
img_height = 96
img_width = 96
val_split=0.15
batch_size = 64

train_datagen = ImageDataGenerator(
    rescale=1.0 / 255.0,
    validation_split=val_split,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Generador del conjunto de entrenamiento
train_generator = train_datagen.flow_from_directory(
    images_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    classes=selected_classes,
    shuffle=True
)

# Generador del conjunto de validación
validation_generator = train_datagen.flow_from_directory(
    images_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    classes=selected_classes,
    shuffle=False
)
# Out:
# Found 42500 images belonging to 10 classes.
# Found 7500 images belonging to 10 classes.

# %%
# Agrega repetición y precarga
train_dataset = tf.data.Dataset.from_generator(
    lambda: train_generator,
    output_signature=(
        tf.TensorSpec(shape=(None, img_height, img_width, 3), dtype=tf.float32),
        tf.TensorSpec(shape=(None, num_categories), dtype=tf.float32)
    )
)

validation_dataset = tf.data.Dataset.from_generator(
    lambda: validation_generator,
    output_signature=(
        tf.TensorSpec(shape=(None, img_height, img_width, 3), dtype=tf.float32),
        tf.TensorSpec(shape=(None, num_categories), dtype=tf.float32)
    )
)

train_dataset = train_dataset.repeat().prefetch(tf.data.AUTOTUNE)
validation_dataset = validation_dataset.repeat().prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# ***Definición del modelo***

# %%
import visualkeras
from tensorflow.keras.utils import plot_model
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam

# %%
# Parámetros usados para entrenar

# Tamaño del filtro
kernel_size = (3, 3)

# Funciones de activación
layer_activation = "relu"
output_activation = "softmax"

# Tamaño después de convolución
padding = "same"

# Reducción
pool_size = (2, 2)

# Tasa de aprendizaje
learning_rate = 0.001

# Optimizador
optimizer = Adam(learning_rate=learning_rate)

# Medición del rendimiento
loss = "categorical_crossentropy"
metrics = ["accuracy"]

# Duración del entrenamiento
epochs = 90

# Ajusta dinámicamente la tasa de entrenamiento cuando no hay mejora
reduce_lr = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.8,
    patience=3,
    min_lr=5e-6
)


# Detención temprana del entrenamiento
early_stopping = EarlyStopping(
    monitor="val_loss",
    patience=9,
    restore_best_weights=True
)

callbacks = [reduce_lr, early_stopping]

# %% [markdown]
# ***Modelo escogido***

# %%
# Arquitectura de modelo
model = models.Sequential([

    # Entrada
    layers.Input(shape=(img_height, img_width, 3)),
    
    # Capa 1
    layers.Conv2D(64, (5, 5), activation=layer_activation, padding=padding),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size),

    # Capa 2
    layers.Conv2D(128, (5, 5), activation=layer_activation, padding=padding),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size),

    # Capa 3
    layers.Conv2D(256, kernel_size, activation=layer_activation, padding=padding, kernel_regularizer=regularizers.l2(0.0015)),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size),

    # Capa 4
    layers.Conv2D(512, kernel_size, activation=layer_activation, padding=padding, kernel_regularizer=regularizers.l2(0.0015)),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size),

    # Aplanamiento global
    layers.GlobalAveragePooling2D(),

    # Capa densa 
    layers.Dense(256, activation=layer_activation),
    layers.BatchNormalization(),
    layers.Dropout(0.4), 

    # Capa de salida
    layers.Dense(num_categories, activation=output_activation)
])

# %%
# Compilación del modelo
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# %%
# Resumen del modelo
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 96, 96, 64)          │           4,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 96, 96, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 48, 48, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 48, 48, 128)         │         204,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 48, 48, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 24, 24, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 24, 24, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 24, 24, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 12, 12, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 12, 12, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 12, 12, 512)         │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 6, 6, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 512)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           2,570 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,823,882 (6.96 MB)
#  Trainable params: 1,821,450 (6.95 MB)
#  Non-trainable params: 2,432 (9.50 KB)

# %%
# Visualización del modelo
visualkeras.layered_view(model)
# Out:
# C:\Users\Victor Mendez\AppData\Roaming\Python\Python312\site-packages\visualkeras\layered.py:86: UserWarning: The legend_text_spacing_offset parameter is deprecated and will be removed in a future release.
#   warnings.warn("The legend_text_spacing_offset parameter is deprecated and will be removed in a future release.")
# <PIL.Image.Image image mode=RGBA size=746x512>

# %%
# Entrenamiento
history = model.fit(
    train_dataset,
    epochs=epochs,
    callbacks=callbacks,
    validation_data=validation_dataset,
    validation_steps=validation_generator.samples // batch_size,
    steps_per_epoch=train_generator.samples // batch_size,
)
# Out:
# Epoch 1/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 947s 1s/step - accuracy: 0.3959 - loss: 2.5755 - val_accuracy: 0.4416 - val_loss: 1.7630 - learning_rate: 0.0010
# Epoch 2/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 974s 1s/step - accuracy: 0.4882 - loss: 1.6882 - val_accuracy: 0.3964 - val_loss: 1.8586 - learning_rate: 0.0010
# Epoch 3/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 965s 1s/step - accuracy: 0.5450 - loss: 1.4336 - val_accuracy: 0.5219 - val_loss: 1.4428 - learning_rate: 0.0010
# Epoch 4/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 939s 1s/step - accuracy: 0.5707 - loss: 1.3534 - val_accuracy: 0.5164 - val_loss: 1.5413 - learning_rate: 0.0010
# Epoch 5/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 930s 1s/step - accuracy: 0.5773 - loss: 1.3701 - val_accuracy: 0.5238 - val_loss: 1.4694 - learning_rate: 0.0010
# Epoch 6/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 936s 1s/step - accuracy: 0.5774 - loss: 1.3534 - val_accuracy: 0.5120 - val_loss: 1.4840 - learning_rate: 0.0010
# Epoch 7/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 931s 1s/step - accuracy: 0.5971 - loss: 1.2661 - val_accuracy: 0.5611 - val_loss: 1.3628 - learning_rate: 8.0000e-04
# Epoch 8/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 902s 1s/step - accuracy: 0.6015 - loss: 1.2712 - val_accuracy: 0.5164 - val_loss: 1.4821 - learning_rate: 8.0000e-04
# Epoch 9/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 903s 1s/step - accuracy: 0.6049 - loss: 1.2539 - val_accuracy: 0.5325 - val_loss: 1.4663 - learning_rate: 8.0000e-04
# Epoch 10/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 901s 1s/step - accuracy: 0.6042 - loss: 1.2457 - val_accuracy: 0.5347 - val_loss: 1.4216 - learning_rate: 8.0000e-04
# Epoch 11/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 892s 1s/step - accuracy: 0.6083 - loss: 1.2467 - val_accuracy: 0.5787 - val_loss: 1.2782 - learning_rate: 6.4000e-04
# Epoch 12/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 895s 1s/step - accuracy: 0.6299 - loss: 1.1540 - val_accuracy: 0.5928 - val_loss: 1.2381 - learning_rate: 6.4000e-04
# Epoch 13/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 896s 1s/step - accuracy: 0.6251 - loss: 1.1807 - val_accuracy: 0.5733 - val_loss: 1.3530 - learning_rate: 6.4000e-04
# Epoch 14/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 898s 1s/step - accuracy: 0.6264 - loss: 1.1527 - val_accuracy: 0.5764 - val_loss: 1.2795 - learning_rate: 6.4000e-04
# Epoch 15/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 897s 1s/step - accuracy: 0.6404 - loss: 1.1286 - val_accuracy: 0.6023 - val_loss: 1.2200 - learning_rate: 6.4000e-04
# Epoch 16/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 898s 1s/step - accuracy: 0.6390 - loss: 1.1208 - val_accuracy: 0.5910 - val_loss: 1.2403 - learning_rate: 6.4000e-04
# Epoch 17/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 897s 1s/step - accuracy: 0.6437 - loss: 1.1099 - val_accuracy: 0.5737 - val_loss: 1.3037 - learning_rate: 6.4000e-04
# Epoch 18/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 898s 1s/step - accuracy: 0.6415 - loss: 1.1191 - val_accuracy: 0.5689 - val_loss: 1.3239 - learning_rate: 6.4000e-04
# Epoch 19/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 951s 1s/step - accuracy: 0.6502 - loss: 1.0842 - val_accuracy: 0.5818 - val_loss: 1.2768 - learning_rate: 5.1200e-04
# Epoch 20/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 1150s 2s/step - accuracy: 0.6503 - loss: 1.0764 - val_accuracy: 0.5905 - val_loss: 1.2457 - learning_rate: 5.1200e-04
# Epoch 21/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 1011s 2s/step - accuracy: 0.6549 - loss: 1.0637 - val_accuracy: 0.6193 - val_loss: 1.1914 - learning_rate: 5.1200e-04
# Epoch 22/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 927s 1s/step - accuracy: 0.6618 - loss: 1.0546 - val_accuracy: 0.5878 - val_loss: 1.2435 - learning_rate: 5.1200e-04
# Epoch 23/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 915s 1s/step - accuracy: 0.6554 - loss: 1.0653 - val_accuracy: 0.5960 - val_loss: 1.2355 - learning_rate: 5.1200e-04
# Epoch 24/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 911s 1s/step - accuracy: 0.6628 - loss: 1.0390 - val_accuracy: 0.5758 - val_loss: 1.2673 - learning_rate: 5.1200e-04
# Epoch 25/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 911s 1s/step - accuracy: 0.6739 - loss: 1.0051 - val_accuracy: 0.6087 - val_loss: 1.2100 - learning_rate: 4.0960e-04
# Epoch 26/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 905s 1s/step - accuracy: 0.6748 - loss: 1.0078 - val_accuracy: 0.6278 - val_loss: 1.1599 - learning_rate: 4.0960e-04
# Epoch 27/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 904s 1s/step - accuracy: 0.6716 - loss: 1.0157 - val_accuracy: 0.6154 - val_loss: 1.1700 - learning_rate: 4.0960e-04
# Epoch 28/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 903s 1s/step - accuracy: 0.6738 - loss: 1.0142 - val_accuracy: 0.6010 - val_loss: 1.2394 - learning_rate: 4.0960e-04
# Epoch 29/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 905s 1s/step - accuracy: 0.6720 - loss: 1.0124 - val_accuracy: 0.6239 - val_loss: 1.1420 - learning_rate: 4.0960e-04
# Epoch 30/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 899s 1s/step - accuracy: 0.6755 - loss: 1.0074 - val_accuracy: 0.6151 - val_loss: 1.1523 - learning_rate: 4.0960e-04
# Epoch 31/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 905s 1s/step - accuracy: 0.6784 - loss: 0.9976 - val_accuracy: 0.6388 - val_loss: 1.1171 - learning_rate: 4.0960e-04
# Epoch 32/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 932s 1s/step - accuracy: 0.6797 - loss: 0.9909 - val_accuracy: 0.6099 - val_loss: 1.2124 - learning_rate: 4.0960e-04
# Epoch 33/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 964s 1s/step - accuracy: 0.6778 - loss: 0.9894 - val_accuracy: 0.6027 - val_loss: 1.2593 - learning_rate: 4.0960e-04
# Epoch 34/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 902s 1s/step - accuracy: 0.6839 - loss: 0.9757 - val_accuracy: 0.6046 - val_loss: 1.2209 - learning_rate: 4.0960e-04
# Epoch 35/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 900s 1s/step - accuracy: 0.6941 - loss: 0.9518 - val_accuracy: 0.6335 - val_loss: 1.1282 - learning_rate: 3.2768e-04
# Epoch 36/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 899s 1s/step - accuracy: 0.6840 - loss: 0.9649 - val_accuracy: 0.6177 - val_loss: 1.1970 - learning_rate: 3.2768e-04
# Epoch 37/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 898s 1s/step - accuracy: 0.6919 - loss: 0.9591 - val_accuracy: 0.6304 - val_loss: 1.1330 - learning_rate: 3.2768e-04
# Epoch 38/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 906s 1s/step - accuracy: 0.6939 - loss: 0.9563 - val_accuracy: 0.6474 - val_loss: 1.1045 - learning_rate: 2.6214e-04
# Epoch 39/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 907s 1s/step - accuracy: 0.6962 - loss: 0.9366 - val_accuracy: 0.6349 - val_loss: 1.1010 - learning_rate: 2.6214e-04
# Epoch 40/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 902s 1s/step - accuracy: 0.7041 - loss: 0.9166 - val_accuracy: 0.6452 - val_loss: 1.0917 - learning_rate: 2.6214e-04
# Epoch 41/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 909s 1s/step - accuracy: 0.7051 - loss: 0.9181 - val_accuracy: 0.6425 - val_loss: 1.1013 - learning_rate: 2.6214e-04
# Epoch 42/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 912s 1s/step - accuracy: 0.7042 - loss: 0.9092 - val_accuracy: 0.6368 - val_loss: 1.1225 - learning_rate: 2.6214e-04
# Epoch 43/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 911s 1s/step - accuracy: 0.7056 - loss: 0.9143 - val_accuracy: 0.6166 - val_loss: 1.1640 - learning_rate: 2.6214e-04
# Epoch 44/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 912s 1s/step - accuracy: 0.7089 - loss: 0.8966 - val_accuracy: 0.6369 - val_loss: 1.1025 - learning_rate: 2.0972e-04
# Epoch 45/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 913s 1s/step - accuracy: 0.7109 - loss: 0.8891 - val_accuracy: 0.6401 - val_loss: 1.0866 - learning_rate: 2.0972e-04
# Epoch 46/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 938s 1s/step - accuracy: 0.7086 - loss: 0.8966 - val_accuracy: 0.6395 - val_loss: 1.0798 - learning_rate: 2.0972e-04
# Epoch 47/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 958s 1s/step - accuracy: 0.7120 - loss: 0.8882 - val_accuracy: 0.6481 - val_loss: 1.0693 - learning_rate: 2.0972e-04
# Epoch 48/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 983s 1s/step - accuracy: 0.7119 - loss: 0.8860 - val_accuracy: 0.6407 - val_loss: 1.1191 - learning_rate: 2.0972e-04
# Epoch 49/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 974s 1s/step - accuracy: 0.7137 - loss: 0.8842 - val_accuracy: 0.6373 - val_loss: 1.1089 - learning_rate: 2.0972e-04
# Epoch 50/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 955s 1s/step - accuracy: 0.7147 - loss: 0.8720 - val_accuracy: 0.6481 - val_loss: 1.0613 - learning_rate: 2.0972e-04
# Epoch 51/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 932s 1s/step - accuracy: 0.7117 - loss: 0.8780 - val_accuracy: 0.6464 - val_loss: 1.1235 - learning_rate: 2.0972e-04
# Epoch 52/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 889s 1s/step - accuracy: 0.7146 - loss: 0.8788 - val_accuracy: 0.6427 - val_loss: 1.0831 - learning_rate: 2.0972e-04
# Epoch 53/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 894s 1s/step - accuracy: 0.7143 - loss: 0.8747 - val_accuracy: 0.6377 - val_loss: 1.1189 - learning_rate: 2.0972e-04
# Epoch 54/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 900s 1s/step - accuracy: 0.7247 - loss: 0.8486 - val_accuracy: 0.6497 - val_loss: 1.0693 - learning_rate: 1.6777e-04
# Epoch 55/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 898s 1s/step - accuracy: 0.7219 - loss: 0.8577 - val_accuracy: 0.6448 - val_loss: 1.0978 - learning_rate: 1.6777e-04
# Epoch 56/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 896s 1s/step - accuracy: 0.7258 - loss: 0.8441 - val_accuracy: 0.6421 - val_loss: 1.1151 - learning_rate: 1.6777e-04
# Epoch 57/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 898s 1s/step - accuracy: 0.7292 - loss: 0.8371 - val_accuracy: 0.6514 - val_loss: 1.0682 - learning_rate: 1.3422e-04
# Epoch 58/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 897s 1s/step - accuracy: 0.7317 - loss: 0.8201 - val_accuracy: 0.6481 - val_loss: 1.0931 - learning_rate: 1.3422e-04
# Epoch 59/90
# 664/664 ━━━━━━━━━━━━━━━━━━━━ 900s 1s/step - accuracy: 0.7327 - loss: 0.8288 - val_accuracy: 0.6459 - val_loss: 1.0936 - learning_rate: 1.3422e-04

# %%
# Guarda el modelo
model.save("trained_model.keras")

# %%
import matplotlib.pyplot as plt

# %%
# Extrae métricas del modelo
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

# Rango de epocas entrenadas 
range_epochs = range(1, len(train_loss) + 1)

# Crea la figura con dos subgráficas
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Gráfica de pérdida
axs[0].plot(range_epochs, train_loss, label='Entrenamiento', marker='o')
axs[0].plot(range_epochs, val_loss, label='Validación', marker='o')
axs[0].set_title('Pérdida a través de las épocas')
axs[0].set_xlabel('Épocas')
axs[0].set_ylabel('Pérdida')
axs[0].legend()
axs[0].grid()

# Gráfica de precisión
axs[1].plot(range_epochs, train_acc, label='Entrenamiento', marker='o')
axs[1].plot(range_epochs, val_acc, label='Validación', marker='o')
axs[1].set_title('Precisión a través de las épocas')
axs[1].set_xlabel('Épocas')
axs[1].set_ylabel('Precisión')
axs[1].legend()
axs[1].grid()

# Muestra las gráficas
plt.tight_layout()
plt.savefig("training_model.png", dpi=300)
plt.show()
